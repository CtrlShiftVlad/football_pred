# %%
import soccerdata as sd

fbref = sd.FBref(leagues="ENG-Premier League", seasons="2023-2024")

# season-level team stats
standard = fbref.read_team_season_stats(stat_type="standard")
shooting = fbref.read_team_season_stats(stat_type="shooting")
passing = fbref.read_team_season_stats(stat_type="passing")

# player season stats
players = fbref.read_player_season_stats(stat_type="standard")

# match-by-match (schedule+results)
schedule = fbref.read_schedule()

# detailed per-match team stats
match_stats = fbref.read_team_match_stats(stat_type="schedule")
# Out:
#   Cell In[1], line 3
#     fbref = sd.FBref(leagues=)
#                      ^
# SyntaxError: expected argument value expression

# %%
""
